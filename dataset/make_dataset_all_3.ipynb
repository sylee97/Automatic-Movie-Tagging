# %%
# all_data_extracted.csv 불러오기
# original_idx,imdb_id,tags_idx
import pandas as pd
df = pd.read_csv('./all_data.csv')

# %%
df2 = pd.read_csv('./tag_list_mood2.csv')

# %%
print(df2)
# Out:
#             Tag
# 0      violence
# 1      romantic
# 2        comedy
# 3   suspenseful
# 4         humor
# 5        action
# 6        sadist
# 7       tragedy
# 8       fantasy
# 9        boring
# 10      mystery
# 11       horror
# 12     dramatic
# 13         dark
# 14  atmospheric
# 15  sentimental
# 16        bleak
# 17   depressing
# 18         cute
# 19    inspiring
# 20        comic
# 21    feel-good

# %%
print(df)
# Out:
#      original_idx    imdb_id  \
# 0               0  tt0023427
# 1               1  tt0029583
# 2               2  tt0031381
# 3               3  tt0032910
# 4               5  tt0034492
# ..            ...        ...
# 982          1195  tt0116629
# 983          1196  tt0116683
# 984          1197  tt0116695
# 985          1198  tt0116705
# 986          1199  tt0116722
#
#                                               tags_idx
# 0                                      violence;murder
# 1    fantasy;murder;cute;good versus evil;romantic;...
# 2          romantic;boring;historical;murder;melodrama
# 3                            cute;fantasy;entertaining
# 4                                                 cute
# ..                                                 ...
# 982  mystery;stupid;cult;humor;action;tragedy;suspe...
# 983                    cult;fantasy;psychedelic;sadist
# 984                              comedy;humor;romantic
# 985                                              comic
# 986                                            tragedy
#
# [987 rows x 3 columns]

# %%
imdb_id_list = df['imdb_id'].tolist()
print(imdb_id_list)
# Out:
# ['tt0023427', 'tt0029583', 'tt0031381', 'tt0032910', 'tt0034492', 'tt0035896', 'tt0040746', 'tt0041716', 'tt0043274', 'tt0043379', 'tt0044926', 'tt0045125', 'tt0045152', 'tt0045810', 'tt0045888', 'tt0045963', 'tt0046183', 'tt0046303', 'tt0046672', 'tt0046912', 'tt0047396', 'tt0047472', 'tt0047673', 'tt0047834', 'tt0047849', 'tt0048545', 'tt0048728', 'tt0049223', 'tt0049261', 'tt0049966', 'tt0050419', 'tt0051459', 'tt0051554', 'tt0051658', 'tt0052357', 'tt0052905', 'tt0052918', 'tt0052948', 'tt0053172', 'tt0053221', 'tt0054047', 'tt0054195', 'tt0054331', 'tt0054494', 'tt0054698', 'tt0054847', 'tt0055257', 'tt0055304', 'tt0055471', 'tt0055614', 'tt0055928', 'tt0056172', 'tt0056264', 'tt0056923', 'tt0057076', 'tt0057197', 'tt0058150', 'tt0058329', 'tt0058385', 'tt0058571', 'tt0058672', 'tt0058777', 'tt0059017', 'tt0059113', 'tt0059125', 'tt0059800', 'tt0060345', 'tt0063442', 'tt0063518', 'tt0063522', 'tt0064276', 'tt0064603', 'tt0064665', 'tt0064782', 'tt0065054', 'tt0065063', 'tt0065088', 'tt0065112', 'tt0065134', 'tt0065207', 'tt0065377', 'tt0065462', 'tt0065724', 'tt0065738', 'tt0066206', 'tt0066214', 'tt0066434', 'tt0066808', 'tt0066995', 'tt0066999', 'tt0067023', 'tt0067065', 'tt0067093', 'tt0067185', 'tt0067309', 'tt0067741', 'tt0067756', 'tt0067800', 'tt0067959', 'tt0067992', 'tt0068240', 'tt0068327', 'tt0068473', 'tt0068555', 'tt0068611', 'tt0068699', 'tt0068762', 'tt0069097', 'tt0069280', 'tt0069281', 'tt0069704', 'tt0069762', 'tt0069865', 'tt0069995', 'tt0070016', 'tt0070034', 'tt0070239', 'tt0070328', 'tt0070355', 'tt0070379', 'tt0070511', 'tt0070608', 'tt0070666', 'tt0070698', 'tt0071110', 'tt0071129', 'tt0071230', 'tt0071315', 'tt0071402', 'tt0071455', 'tt0071569', 'tt0071853', 'tt0071994', 'tt0072288', 'tt0072684', 'tt0072890', 'tt0073018', 'tt0073195', 'tt0073440', 'tt0073486', 'tt0073540', 'tt0073812', 'tt0074119', 'tt0074256', 'tt0074285', 'tt0074455', 'tt0074512', 'tt0074860', 'tt0074937', 'tt0074958', 'tt0074991', 'tt0075222', 'tt0075223', 'tt0075261', 'tt0075314', 'tt0075648', 'tt0075860', 'tt0076009', 'tt0076141', 'tt0076451', 'tt0076538', 'tt0076578', 'tt0076636', 'tt0076716', 'tt0076929', 'tt0077235', 'tt0077394', 'tt0077402', 'tt0077405', 'tt0077413', 'tt0077523', 'tt0077572', 'tt0077578', 'tt0077663', 'tt0077742', 'tt0077745', 'tt0077975', 'tt0078087', 'tt0078158', 'tt0078480', 'tt0078721', 'tt0078723', 'tt0078748', 'tt0078754', 'tt0078788', 'tt0078902', 'tt0079116', 'tt0079261', 'tt0079285', 'tt0079417', 'tt0079489', 'tt0079501', 'tt0079522', 'tt0079540', 'tt0079574', 'tt0079817', 'tt0080025', 'tt0080031', 'tt0080319', 'tt0080339', 'tt0080360', 'tt0080365', 'tt0080377', 'tt0080391', 'tt0080421', 'tt0080472', 'tt0080474', 'tt0080487', 'tt0080661', 'tt0080684', 'tt0080745', 'tt0080761', 'tt0080923', 'tt0080979', 'tt0081114', 'tt0081207', 'tt0081283', 'tt0081375', 'tt0081383', 'tt0081455', 'tt0081505', 'tt0081534', 'tt0081573', 'tt0081696', 'tt0081748', 'tt0082009', 'tt0082031', 'tt0082085', 'tt0082089', 'tt0082158', 'tt0082220', 'tt0082288', 'tt0082340', 'tt0082348', 'tt0082398', 'tt0082418', 'tt0082432', 'tt0082449', 'tt0082495', 'tt0082498', 'tt0082509', 'tt0082517', 'tt0082727', 'tt0082766', 'tt0082782', 'tt0082846', 'tt0082869', 'tt0082933', 'tt0082970', 'tt0082971', 'tt0083284', 'tt0083511', 'tt0083530', 'tt0083542', 'tt0083564', 'tt0083624', 'tt0083658', 'tt0083722', 'tt0083767', 'tt0083806', 'tt0083929', 'tt0083943', 'tt0083944', 'tt0084021', 'tt0084112', 'tt0084370', 'tt0084503', 'tt0084516', 'tt0084522', 'tt0084602', 'tt0084707', 'tt0084777', 'tt0084786', 'tt0084805', 'tt0084854', 'tt0085204', 'tt0085255', 'tt0085271', 'tt0085276', 'tt0085382', 'tt0085475', 'tt0085636', 'tt0085672', 'tt0085701', 'tt0085724', 'tt0085750', 'tt0085809', 'tt0085811', 'tt0085970', 'tt0085980', 'tt0085995', 'tt0086034', 'tt0086143', 'tt0086154', 'tt0086190', 'tt0086200', 'tt0086250', 'tt0086320', 'tt0086361', 'tt0086383', 'tt0086425', 'tt0086450', 'tt0086508', 'tt0086525', 'tt0086541', 'tt0086567', 'tt0086859', 'tt00868 ...

# %%
mood_tag_list = df2['Tag'].tolist()
print(mood_tag_list)
# Out:
# ['violence', 'romantic', 'comedy', 'suspenseful', 'humor', 'action', 'sadist', 'tragedy', 'fantasy', 'boring', 'mystery', 'horror', 'dramatic', 'dark', 'atmospheric', 'sentimental', 'bleak', 'depressing', 'cute', 'inspiring', 'comic', 'feel-good']

# %%
# s1_tag_idx에서 stft로 추출된 파일 목록 행을 추출
mpst_tag=df['tags_idx']
print(mpst_tag)
# Out:
# 0                                        violence;murder
# 1      fantasy;murder;cute;good versus evil;romantic;...
# 2            romantic;boring;historical;murder;melodrama
# 3                              cute;fantasy;entertaining
# 4                                                   cute
#                              ...
# 982    mystery;stupid;cult;humor;action;tragedy;suspe...
# 983                      cult;fantasy;psychedelic;sadist
# 984                                comedy;humor;romantic
# 985                                                comic
# 986                                              tragedy
# Name: tags_idx, Length: 987, dtype: object

# %%
mpst_tag_list=mpst_tag.tolist()
print(mpst_tag_list)
# Out:
# ['violence;murder', 'fantasy;murder;cute;good versus evil;romantic;entertaining', 'romantic;boring;historical;murder;melodrama', 'cute;fantasy;entertaining', 'cute', 'violence;murder', 'murder;cult;atmospheric;philosophical;suspenseful;storytelling', 'romantic', 'fantasy;whimsical;cute;alternate reality;psychedelic;entertaining', 'violence;action;historical fiction', 'romantic', 'revenge;action;murder', 'comedy;boring;flashback;satire;romantic;historical', 'romantic;satire', 'revenge;murder', 'romantic', 'good versus evil;psychedelic;fantasy;action;entertaining', 'revenge;murder;violence;melodrama', 'sci-fi', 'suspenseful;murder;claustrophobic', 'mystery;suspenseful;horror;murder;claustrophobic', 'romantic', 'romantic', 'allegory;psychedelic;satire;murder', 'cult;murder', 'cult;violence;romantic', 'murder;atmospheric', 'comedy;psychological;murder;cult;psychedelic;suspenseful;sci-fi', 'romantic;depressing;realism;melodrama', 'melodrama;revenge;psychedelic;romantic;flashback', 'philosophical', 'sentimental', 'gothic;paranormal;cult;violence;good versus evil;suspenseful', 'romantic', 'mystery;murder;cult;atmospheric;flashback;psychedelic;romantic;plot twist', 'gothic;murder;atmospheric', 'melodrama', 'murder', 'romantic;comedy', 'good versus evil;cult;suspenseful;psychedelic;humor', 'revenge;cult;murder;violence', 'romantic', 'tragedy;romantic;historical;murder;violence', 'absurd;psychedelic', 'cult;psychedelic;humor;satire;melodrama;romantic;sentimental', 'violence', 'revenge;cult', 'insanity;cult;gothic;murder;flashback', 'romantic;melodrama', 'tragedy;revenge;murder;romantic;entertaining', 'good versus evil;cult;murder', 'murder;cult;violence;atmospheric;flashback;insanity;historical', 'action', 'romantic;humor;murder', 'cult;murder', 'cult;murder', 'suspenseful;murder;cult;action;humor;revenge', 'melodrama;romantic;psychological;murder;flashback', 'romantic;entertaining;clever', 'romantic', 'suspenseful;intrigue', 'cult;historical', 'revenge', 'avant garde;murder;atmospheric;romantic;revenge;historical', 'revenge', 'cult;humor;murder;suspenseful', 'cult;fantasy;psychedelic;entertaining;humor', 'murder;allegory;dramatic;cult;violence;satire;suspenseful', 'murder;cult;action;romantic;tragedy;revenge', 'murder;horror;atmospheric;good versus evil;psychedelic;suspenseful', 'comedy;avant garde;dark;murder;realism;cult;atmospheric;psychedelic;humor;satire', 'cult', 'tragedy;psychedelic;humor;realism;flashback', 'cult;comedy', 'tragedy', 'comedy;satire;entertaining', 'depressing;flashback', 'suspenseful;intrigue;murder', 'cult;avant garde;murder;violence', 'plot twist;violence;romantic;flashback', 'cult;suspenseful;melodrama', 'murder;allegory;anti war;violence;cult;flashback;good versus evil;action;satire;suspenseful', 'cult;romantic', 'insanity;gothic;murder', 'violence;boring;historical', 'mystery;murder;cult;violence;atmospheric;psychedelic', 'avant garde;suspenseful;murder;neo noir;psychological;cult;psychedelic;romantic;sci-fi', 'cult;comedy;satire', 'cult;revenge;murder', 'dark;suspenseful;cruelty;murder;neo noir;realism;cult;violence;good versus evil;revenge;sadist', 'mystery;cult;comedy;suspenseful', 'alternate history;murder;flashback', 'avant garde;flashback', 'comedy;dark;cute;cult;psychedelic;humor', 'murder;mystery;neo noir;storytelling;sadist', 'grindhouse film;murder;cult;violence;atmospheric;suspenseful;blaxploitation', 'comedy;murder;cult;atmospheric;flashback;psychedelic;claustrophobic;inspiring', 'suspenseful;cruelty;murder;cult;violence;flashback;revenge;sadist', 'insanity;mystery;storytelling;flashback', 'boring;fantasy;whimsical;cute;cult;psychedelic;entertaining', 'murder', 'romantic;depressing;historical;queer', 'mystery;psychological;realism;murder;cult;violence;suspenseful', 'pornographic;psychedelic;humor;satire', 'murder;cult;revenge;horror;flashback;suspenseful;sadist', 'dark;suspenseful;mystery;murder;bleak;western;violence;cult;flashback;psychedelic;revenge', 'bleak;realism;revenge;murder;atmospheric' ...

# %%
mpst_tag_list_split=[]
for i in range(len(mpst_tag_list)):
    mpst_tag_list_split.append(mpst_tag_list[i].replace("'",'').split(';'))

print(mpst_tag_list_split)
print(len((mpst_tag_list_split)))
# Out:
# [['violence', 'murder'], ['fantasy', 'murder', 'cute', 'good versus evil', 'romantic', 'entertaining'], ['romantic', 'boring', 'historical', 'murder', 'melodrama'], ['cute', 'fantasy', 'entertaining'], ['cute'], ['violence', 'murder'], ['murder', 'cult', 'atmospheric', 'philosophical', 'suspenseful', 'storytelling'], ['romantic'], ['fantasy', 'whimsical', 'cute', 'alternate reality', 'psychedelic', 'entertaining'], ['violence', 'action', 'historical fiction'], ['romantic'], ['revenge', 'action', 'murder'], ['comedy', 'boring', 'flashback', 'satire', 'romantic', 'historical'], ['romantic', 'satire'], ['revenge', 'murder'], ['romantic'], ['good versus evil', 'psychedelic', 'fantasy', 'action', 'entertaining'], ['revenge', 'murder', 'violence', 'melodrama'], ['sci-fi'], ['suspenseful', 'murder', 'claustrophobic'], ['mystery', 'suspenseful', 'horror', 'murder', 'claustrophobic'], ['romantic'], ['romantic'], ['allegory', 'psychedelic', 'satire', 'murder'], ['cult', 'murder'], ['cult', 'violence', 'romantic'], ['murder', 'atmospheric'], ['comedy', 'psychological', 'murder', 'cult', 'psychedelic', 'suspenseful', 'sci-fi'], ['romantic', 'depressing', 'realism', 'melodrama'], ['melodrama', 'revenge', 'psychedelic', 'romantic', 'flashback'], ['philosophical'], ['sentimental'], ['gothic', 'paranormal', 'cult', 'violence', 'good versus evil', 'suspenseful'], ['romantic'], ['mystery', 'murder', 'cult', 'atmospheric', 'flashback', 'psychedelic', 'romantic', 'plot twist'], ['gothic', 'murder', 'atmospheric'], ['melodrama'], ['murder'], ['romantic', 'comedy'], ['good versus evil', 'cult', 'suspenseful', 'psychedelic', 'humor'], ['revenge', 'cult', 'murder', 'violence'], ['romantic'], ['tragedy', 'romantic', 'historical', 'murder', 'violence'], ['absurd', 'psychedelic'], ['cult', 'psychedelic', 'humor', 'satire', 'melodrama', 'romantic', 'sentimental'], ['violence'], ['revenge', 'cult'], ['insanity', 'cult', 'gothic', 'murder', 'flashback'], ['romantic', 'melodrama'], ['tragedy', 'revenge', 'murder', 'romantic', 'entertaining'], ['good versus evil', 'cult', 'murder'], ['murder', 'cult', 'violence', 'atmospheric', 'flashback', 'insanity', 'historical'], ['action'], ['romantic', 'humor', 'murder'], ['cult', 'murder'], ['cult', 'murder'], ['suspenseful', 'murder', 'cult', 'action', 'humor', 'revenge'], ['melodrama', 'romantic', 'psychological', 'murder', 'flashback'], ['romantic', 'entertaining', 'clever'], ['romantic'], ['suspenseful', 'intrigue'], ['cult', 'historical'], ['revenge'], ['avant garde', 'murder', 'atmospheric', 'romantic', 'revenge', 'historical'], ['revenge'], ['cult', 'humor', 'murder', 'suspenseful'], ['cult', 'fantasy', 'psychedelic', 'entertaining', 'humor'], ['murder', 'allegory', 'dramatic', 'cult', 'violence', 'satire', 'suspenseful'], ['murder', 'cult', 'action', 'romantic', 'tragedy', 'revenge'], ['murder', 'horror', 'atmospheric', 'good versus evil', 'psychedelic', 'suspenseful'], ['comedy', 'avant garde', 'dark', 'murder', 'realism', 'cult', 'atmospheric', 'psychedelic', 'humor', 'satire'], ['cult'], ['tragedy', 'psychedelic', 'humor', 'realism', 'flashback'], ['cult', 'comedy'], ['tragedy'], ['comedy', 'satire', 'entertaining'], ['depressing', 'flashback'], ['suspenseful', 'intrigue', 'murder'], ['cult', 'avant garde', 'murder', 'violence'], ['plot twist', 'violence', 'romantic', 'flashback'], ['cult', 'suspenseful', 'melodrama'], ['murder', 'allegory', 'anti war', 'violence', 'cult', 'flashback', 'good versus evil', 'action', 'satire', 'suspenseful'], ['cult', 'romantic'], ['insanity', 'gothic', 'murder'], ['violence', 'boring', 'historical'], ['mystery', 'murder', 'cult', 'violence', 'atmospheric', 'psychedelic'], ['avant garde', 'suspenseful', 'murder', 'neo noir', 'psychological', 'cult', 'psychedelic', 'romantic', 'sci-fi'], ['cult', 'comedy', 'satire'], ['cult', 'revenge', 'murder'], ['dark', 'suspenseful', 'cruelty', 'murder', 'neo noir', 'realism', 'cult', 'violence', 'good versus evil', 'revenge', 'sadist'], [ ...
# 987

# %%
for i in range(len(mpst_tag_list_split)):
    for tag in mpst_tag_list_split[i]:
        if tag not in mood_tag_list: # 태그가 mood_tag_list에 없다면
            mpst_tag_list_split[i].remove(tag) # 해당 태그 제거

# %%
print(mpst_tag_list_split)
print(len(mpst_tag_list_split))
# Out:
# [['violence'], ['fantasy', 'cute', 'romantic'], ['romantic', 'boring'], ['cute', 'fantasy'], ['cute'], ['violence'], ['atmospheric', 'suspenseful'], ['romantic'], ['fantasy', 'cute'], ['violence', 'action'], ['romantic'], ['action'], ['comedy', 'boring', 'romantic'], ['romantic'], [], ['romantic'], ['fantasy', 'action'], ['violence'], [], ['suspenseful'], ['mystery', 'suspenseful', 'horror'], ['romantic'], ['romantic'], ['murder'], [], ['violence', 'romantic'], ['atmospheric'], ['comedy', 'psychedelic', 'suspenseful'], ['romantic', 'depressing'], ['romantic'], [], ['sentimental'], ['violence', 'suspenseful'], ['romantic'], ['mystery', 'atmospheric', 'romantic'], ['atmospheric'], [], [], ['romantic', 'comedy'], ['suspenseful', 'humor'], ['violence'], ['romantic'], ['tragedy', 'romantic', 'violence'], [], ['humor', 'romantic', 'sentimental'], ['violence'], [], ['murder'], ['romantic'], ['tragedy', 'romantic'], [], ['violence', 'atmospheric'], ['action'], ['romantic', 'humor'], [], [], ['suspenseful', 'action', 'humor'], ['romantic'], ['romantic'], ['romantic'], ['suspenseful'], [], [], ['atmospheric', 'romantic'], [], ['humor', 'suspenseful'], ['fantasy', 'humor'], ['dramatic', 'violence', 'suspenseful'], ['action', 'romantic', 'tragedy'], ['horror', 'atmospheric', 'suspenseful'], ['comedy', 'dark', 'atmospheric', 'humor'], [], ['tragedy', 'humor'], ['comedy'], ['tragedy'], ['comedy'], ['depressing'], ['suspenseful'], ['violence'], ['violence', 'romantic'], ['suspenseful'], ['violence', 'action', 'suspenseful'], ['romantic'], [], ['violence', 'boring'], ['mystery', 'violence', 'atmospheric'], ['suspenseful', 'cult', 'romantic'], ['comedy'], [], ['dark', 'suspenseful', 'realism', 'violence', 'sadist'], ['mystery', 'comedy', 'suspenseful'], [], [], ['comedy', 'dark', 'cute', 'humor'], ['mystery', 'sadist'], ['violence', 'atmospheric', 'suspenseful'], ['comedy', 'atmospheric', 'inspiring'], ['suspenseful', 'violence', 'sadist'], ['mystery'], ['boring', 'fantasy', 'cute'], [], ['romantic', 'depressing'], ['mystery', 'cult', 'violence', 'suspenseful'], ['humor'], ['horror', 'suspenseful', 'sadist'], ['dark', 'suspenseful', 'mystery', 'bleak', 'violence', 'revenge'], ['bleak', 'atmospheric'], ['romantic'], ['boring', 'absurd'], ['mystery', 'revenge', 'suspenseful'], ['romantic'], ['bleak', 'atmospheric', 'violence'], ['suspenseful'], ['atmospheric', 'suspenseful'], ['romantic', 'cute', 'sentimental'], ['suspenseful', 'violence'], ['boring'], ['murder', 'violence'], ['violence'], ['comedy', 'violence'], ['violence', 'boring', 'romantic'], ['action'], ['dark', 'violence', 'atmospheric', 'romantic'], ['cult', 'claustrophobic'], ['suspenseful'], ['humor'], ['comedy', 'absurd', 'comic'], ['comedy', 'dark', 'depressing', 'mystery', 'bleak', 'violence', 'atmospheric', 'humor', 'suspenseful'], ['murder', 'violence'], ['comedy', 'suspenseful', 'revenge'], ['action'], ['comedy', 'violence', 'humor'], ['dark', 'comedy', 'cult', 'violence', 'tragedy'], ['violence', 'comedy'], ['boring', 'atmospheric'], ['comedy', 'atmospheric'], [], ['horror', 'suspenseful', 'violence'], ['tragedy', 'humor', 'atmospheric'], ['depressing', 'dramatic', 'violence', 'sadist', 'sentimental'], ['mystery', 'boring'], ['humor', 'boring'], ['inspiring', 'suspenseful', 'mystery', 'dramatic'], ['depressing', 'comic'], ['comedy', 'fantasy', 'suspenseful', 'dark', 'violence', 'horror', 'atmospheric', 'romantic', 'tragedy', 'sadist'], ['horror', 'violence'], ['suspenseful'], ['suspenseful', 'violence', 'horror'], ['mystery'], ['comedy', 'dramatic', 'atmospheric', 'humor'], ['violence'], ['comedy'], ['comedy', 'violence'], [], ['dark', 'boring', 'violence', 'atmospheric', 'romantic'], ['suspenseful'], ['mystery', 'dramatic', 'humor'], [], [], ['romantic'], ['action', 'boring'], ['boring'], ['suspenseful', 'comedy'], [], ['fantasy', 'violence', 'absurd', 'romantic'], [], ['violence'], ['comedy', 'suspenseful', 'horror', 'violence', 'action', 'entertaining', 'sadist'], ['tragedy' ...
# 987

# %%
tag_str=[]
for i in range(len(mpst_tag_list_split)):
    str=""
    for tag in mpst_tag_list_split[i]:
        str+=tag+';'
    str=str[:-1]
    tag_str.append(str)

print(tag_str)
# Out:
# ['violence', 'fantasy;cute;romantic', 'romantic;boring', 'cute;fantasy', 'cute', 'violence', 'atmospheric;suspenseful', 'romantic', 'fantasy;cute', 'violence;action', 'romantic', 'action', 'comedy;boring;romantic', 'romantic', '', 'romantic', 'fantasy;action', 'violence', '', 'suspenseful', 'mystery;suspenseful;horror', 'romantic', 'romantic', 'murder', '', 'violence;romantic', 'atmospheric', 'comedy;psychedelic;suspenseful', 'romantic;depressing', 'romantic', '', 'sentimental', 'violence;suspenseful', 'romantic', 'mystery;atmospheric;romantic', 'atmospheric', '', '', 'romantic;comedy', 'suspenseful;humor', 'violence', 'romantic', 'tragedy;romantic;violence', '', 'humor;romantic;sentimental', 'violence', '', 'murder', 'romantic', 'tragedy;romantic', '', 'violence;atmospheric', 'action', 'romantic;humor', '', '', 'suspenseful;action;humor', 'romantic', 'romantic', 'romantic', 'suspenseful', '', '', 'atmospheric;romantic', '', 'humor;suspenseful', 'fantasy;humor', 'dramatic;violence;suspenseful', 'action;romantic;tragedy', 'horror;atmospheric;suspenseful', 'comedy;dark;atmospheric;humor', '', 'tragedy;humor', 'comedy', 'tragedy', 'comedy', 'depressing', 'suspenseful', 'violence', 'violence;romantic', 'suspenseful', 'violence;action;suspenseful', 'romantic', '', 'violence;boring', 'mystery;violence;atmospheric', 'suspenseful;cult;romantic', 'comedy', '', 'dark;suspenseful;realism;violence;sadist', 'mystery;comedy;suspenseful', '', '', 'comedy;dark;cute;humor', 'mystery;sadist', 'violence;atmospheric;suspenseful', 'comedy;atmospheric;inspiring', 'suspenseful;violence;sadist', 'mystery', 'boring;fantasy;cute', '', 'romantic;depressing', 'mystery;cult;violence;suspenseful', 'humor', 'horror;suspenseful;sadist', 'dark;suspenseful;mystery;bleak;violence;revenge', 'bleak;atmospheric', 'romantic', 'boring;absurd', 'mystery;revenge;suspenseful', 'romantic', 'bleak;atmospheric;violence', 'suspenseful', 'atmospheric;suspenseful', 'romantic;cute;sentimental', 'suspenseful;violence', 'boring', 'murder;violence', 'violence', 'comedy;violence', 'violence;boring;romantic', 'action', 'dark;violence;atmospheric;romantic', 'cult;claustrophobic', 'suspenseful', 'humor', 'comedy;absurd;comic', 'comedy;dark;depressing;mystery;bleak;violence;atmospheric;humor;suspenseful', 'murder;violence', 'comedy;suspenseful;revenge', 'action', 'comedy;violence;humor', 'dark;comedy;cult;violence;tragedy', 'violence;comedy', 'boring;atmospheric', 'comedy;atmospheric', '', 'horror;suspenseful;violence', 'tragedy;humor;atmospheric', 'depressing;dramatic;violence;sadist;sentimental', 'mystery;boring', 'humor;boring', 'inspiring;suspenseful;mystery;dramatic', 'depressing;comic', 'comedy;fantasy;suspenseful;dark;violence;horror;atmospheric;romantic;tragedy;sadist', 'horror;violence', 'suspenseful', 'suspenseful;violence;horror', 'mystery', 'comedy;dramatic;atmospheric;humor', 'violence', 'comedy', 'comedy;violence', '', 'dark;boring;violence;atmospheric;romantic', 'suspenseful', 'mystery;dramatic;humor', '', '', 'romantic', 'action;boring', 'boring', 'suspenseful;comedy', '', 'fantasy;violence;absurd;romantic', '', 'violence', 'comedy;suspenseful;horror;violence;action;entertaining;sadist', 'tragedy;boring;atmospheric', 'mystery', 'comedy;violence', '', '', '', 'depressing', 'horror;violence;humor', 'comedy;entertaining', 'tragedy;comedy;violence', '', 'violence;atmospheric;romantic', 'romantic', 'satire', 'dark;boring;mystery;violence;horror;atmospheric;action;suspenseful', 'tragedy;comedy', 'dark;boring;violence;dramatic;action;suspenseful', 'inspiring', 'suspenseful;violence', 'romantic', 'violence', 'dramatic', 'romantic', 'suspenseful;violence;action;tragedy', 'comedy;humor;romantic', '', 'suspenseful', 'violence;romantic', 'violence;romantic', 'violence', '', 'comedy;absurd;humor;romantic', 'violence;romantic;suspenseful', 'sadist', 'violence', '', '', 'violence;comic', 'violence', 'comedy;violence;humor', 'mystery;violence;suspenseful;sadist', 'dark;fantasy;myster ...

# %%
df4 = pd.DataFrame([ x for x in zip(imdb_id_list,tag_str)])
df4.columns=['imdb_id', 'tags']
print(df4)
# Out:
#        imdb_id                                      tags
# 0    tt0023427                                  violence
# 1    tt0029583                     fantasy;cute;romantic
# 2    tt0031381                           romantic;boring
# 3    tt0032910                              cute;fantasy
# 4    tt0034492                                      cute
# ..         ...                                       ...
# 982  tt0116629  mystery;humor;action;tragedy;suspenseful
# 983  tt0116683                            fantasy;sadist
# 984  tt0116695                     comedy;humor;romantic
# 985  tt0116705                                     comic
# 986  tt0116722                                   tragedy
#
# [987 rows x 2 columns]

# %%
item_list = [ x for x in zip(imdb_id_list,tag_str)]
# print(item_list)
# print(type(item_list[0]))
# print(len(item_list))
# print(item_list[986][0])
# print(type(item_list[18][0]))
# item_list.pop(18)
# print(len(item_list))
rmove_item_list=[]
item_list_ext_id=[]
item_list_ext_tag=[]
for i in range(len(item_list)):
    # print(item_list[i])
    if(item_list[i][1]==''):
        rmove_item_list.append(item_list[i][0])
    else:
        item_list_ext_id.append(item_list[i][0])
        item_list_ext_tag.append(item_list[i][1])
        print(item_list[i])
print(len(rmove_item_list))
print(rmove_item_list)
# Out:
# ('tt0023427', 'violence')
# ('tt0029583', 'fantasy;cute;romantic')
# ('tt0031381', 'romantic;boring')
# ('tt0032910', 'cute;fantasy')
# ('tt0034492', 'cute')
# ('tt0035896', 'violence')
# ('tt0040746', 'atmospheric;suspenseful')
# ('tt0041716', 'romantic')
# ('tt0043274', 'fantasy;cute')
# ('tt0043379', 'violence;action')
# ('tt0044926', 'romantic')
# ('tt0045125', 'action')
# ('tt0045152', 'comedy;boring;romantic')
# ('tt0045810', 'romantic')
# ('tt0045963', 'romantic')
# ('tt0046183', 'fantasy;action')
# ('tt0046303', 'violence')
# ('tt0046912', 'suspenseful')
# ('tt0047396', 'mystery;suspenseful;horror')
# ('tt0047472', 'romantic')
# ('tt0047673', 'romantic')
# ('tt0047834', 'murder')
# ('tt0048545', 'violence;romantic')
# ('tt0048728', 'atmospheric')
# ('tt0049223', 'comedy;psychedelic;suspenseful')
# ('tt0049261', 'romantic;depressing')
# ('tt0049966', 'romantic')
# ('tt0051459', 'sentimental')
# ('tt0051554', 'violence;suspenseful')
# ('tt0051658', 'romantic')
# ('tt0052357', 'mystery;atmospheric;romantic')
# ('tt0052905', 'atmospheric')
# ('tt0053172', 'romantic;comedy')
# ('tt0053221', 'suspenseful;humor')
# ('tt0054047', 'violence')
# ('tt0054195', 'romantic')
# ('tt0054331', 'tragedy;romantic;violence')
# ('tt0054698', 'humor;romantic;sentimental')
# ('tt0054847', 'violence')
# ('tt0055304', 'murder')
# ('tt0055471', 'romantic')
# ('tt0055614', 'tragedy;romantic')
# ('tt0056172', 'violence;atmospheric')
# ('tt0056264', 'action')
# ('tt0056923', 'romantic;humor')
# ('tt0058150', 'suspenseful;action;humor')
# ('tt0058329', 'romantic')
# ('tt0058385', 'romantic')
# ('tt0058571', 'romantic')
# ('tt0058672', 'suspenseful')
# ('tt0059113', 'atmospheric;romantic')
# ('tt0059800', 'humor;suspenseful')
# ('tt0060345', 'fantasy;humor')
# ('tt0063442', 'dramatic;violence;suspenseful')
# ('tt0063518', 'action;romantic;tragedy')
# ('tt0063522', 'horror;atmospheric;suspenseful')
# ('tt0064276', 'comedy;dark;atmospheric;humor')
# ('tt0064665', 'tragedy;humor')
# ('tt0064782', 'comedy')
# ('tt0065054', 'tragedy')
# ('tt0065063', 'comedy')
# ('tt0065088', 'depressing')
# ('tt0065112', 'suspenseful')
# ('tt0065134', 'violence')
# ('tt0065207', 'violence;romantic')
# ('tt0065377', 'suspenseful')
# ('tt0065462', 'violence;action;suspenseful')
# ('tt0065724', 'romantic')
# ('tt0066206', 'violence;boring')
# ('tt0066214', 'mystery;violence;atmospheric')
# ('tt0066434', 'suspenseful;cult;romantic')
# ('tt0066808', 'comedy')
# ('tt0066999', 'dark;suspenseful;realism;violence;sadist')
# ('tt0067023', 'mystery;comedy;suspenseful')
# ('tt0067185', 'comedy;dark;cute;humor')
# ('tt0067309', 'mystery;sadist')
# ('tt0067741', 'violence;atmospheric;suspenseful')
# ('tt0067756', 'comedy;atmospheric;inspiring')
# ('tt0067800', 'suspenseful;violence;sadist')
# ('tt0067959', 'mystery')
# ('tt0067992', 'boring;fantasy;cute')
# ('tt0068327', 'romantic;depressing')
# ('tt0068473', 'mystery;cult;violence;suspenseful')
# ('tt0068555', 'humor')
# ('tt0068611', 'horror;suspenseful;sadist')
# ('tt0068699', 'dark;suspenseful;mystery;bleak;violence;revenge')
# ('tt0068762', 'bleak;atmospheric')
# ('tt0069097', 'romantic')
# ('tt0069280', 'boring;absurd')
# ('tt0069281', 'mystery;revenge;suspenseful')
# ('tt0069704', 'romantic')
# ('tt0069762', 'bleak;atmospheric;violence')
# ('tt0069865', 'suspenseful')
# ('tt0069995', 'atmospheric;suspenseful')
# ('tt0070016', 'romantic;cute;sentimental')
# ('tt0070034', 'suspenseful;violence')
# ('tt0070239', 'boring')
# ('tt0070328', 'murder;violence')
# ('tt0070355', 'violence')
# ('tt0070379', 'comedy;violence')
# ('tt0070511', 'violence;boring;romantic')
# ('tt0070608', 'action')
# ('tt0070666', 'dark;violence;atmospheric;romantic')
# ('tt0070698', 'cult;claustrophobic')
# ('tt0071110', 'suspenseful')
# ('tt0071129', 'humor')
# ('tt0071230', 'comedy;absurd;comic')
# ('tt0071315', 'comedy;dark;depressing;mystery;bleak;violence;atmospheric;humor;suspenseful')
# ('tt0071402', 'murder;violence')
# ('tt0071455', 'comedy;suspenseful;revenge')
# ('tt0071569', 'action')
# ('tt0071853', 'comedy;violence;humor')
# ('tt0071994', 'dark;comedy;cult;violence;tragedy')
# ('tt0072288', 'violence;comedy')
# ('tt0072684', 'boring;atmospheric')
# ('tt0072890', 'comedy;atmospheric')
# ('tt0073195', 'horror;suspenseful;violence')
# ('tt0073440', 'tragedy;humor;atmospheric')
# ('tt0073486', 'depressing;dramatic;violence;sadist;sentimental')
# ('tt0073540', 'mystery;boring')
# ('tt0073812', 'humor;boring')
# ('tt0074119', 'inspiring;suspenseful;mystery;dramatic')
# ('tt0074256', 'depressing;comic')
# ('tt0074285', 'comedy;fantasy;suspenseful;dark;violence;horror;atmospheric;romantic;tragedy;sadist')
# ('tt0074455', 'horror;violence')
# ('tt0074512', 'suspenseful')
# ('tt0074860', 'suspenseful;violence;horror')
# ('tt0074937', 'mystery')
# ('tt0074958', 'comedy;dramatic;atmospheric;humor')
# ('tt0074991', 'violence')
# ('tt0075222', 'comedy')
# ('tt0075223', 'comedy;violence')
# ('tt0075314', 'dark;boring;violence;atmospheric;romantic')
# ('tt0075648', 'suspenseful')
# ('tt0075860', 'mystery;dramatic;humor')
# ('tt0076451', 'romantic')
# ('tt0076538', 'action;boring')
# ('tt0076578', 'boring')
# ('tt0076636', 'suspenseful;comedy')
# ('tt0076929', 'fantasy;violence;absurd;romantic')
# ('tt0077394', 'violence')
# ('tt0077402', 'comedy;suspenseful;horror;violence;action;entertaining;sadist')
# ('tt0077405', 'tragedy;boring;atmospheric')
# ('tt0077413', 'mystery')
# ('tt0077523', 'comedy;violence')
# ('tt0077742', 'depressing')
# ('tt0077745', 'horror;violence;humor')
# ('tt0077975', 'comedy;entertaining')
# ('tt0078087', 'tragedy;comedy;violence')
# ('tt0078480', 'violence;atmospheric;romantic')
# ('tt0078721', 'romantic')
# ('tt0078723', 'satire')
# ('tt0078748', 'dark;boring;mystery;violence;horror;atmospheric;action;suspenseful')
# ('tt0078754', 'tragedy;comedy')
# ('tt0078788', 'dark;boring;violence;dramatic;action;suspenseful')
# ('tt0078902', 'inspiring')
# ('tt0079116', 'suspenseful;violence')
# ('tt0079261', 'romantic')
# ('tt0079285', 'violence')
# ('tt0079417', 'dramatic')
# ('tt0079489', 'romantic')
# ('tt0079501', 'suspenseful;violence;action;tragedy')
# ('tt0079522', 'comedy;humor;romantic')
# ('tt0079574', 'suspenseful')
# ('tt0079817', 'violence;romantic')
# ('tt0080025', 'violence;romantic')
# ('tt0080031', 'violence')
# ('tt0080339', 'comedy;absurd;humor;romantic')
# ('tt0080360', 'violence;romantic;suspenseful')
# ('tt0080365', 'sadist')
# ('tt0080377', 'violence')
# ('tt0080472', 'violence;comic')
# ('tt0080474', 'violence')
# ('tt0080487', 'comedy;violence;humor')
# ('tt0080661', 'mystery;violence;suspenseful;sadist')
# ('tt0080684', 'dark;fantasy;mystery;violence;action;tragedy')
# ('tt0080761', 'suspenseful;murder;boring;horror;violence;sadist')
# ('tt0080923', 'dark;violence;horror;atmospheric;suspenseful;sadist')
# ('tt0080979', 'bleak')
# ('tt0081114', 'violence;horror;sadist')
# ('tt0081283', 'romantic;depressing')
# ('tt0081383', 'cult;horror;violence;sadist')
# ('tt0081455', 'violence;tragedy;suspenseful')
# ('tt0081505', 'dark;mystery;horror;atmospheric;suspenseful')
# ('tt0081534', 'cute;romantic')
# ('tt0081573', 'action;violence')
# ('tt0081696', 'violence')
# ('tt0082031', 'comedy')
# ('tt0082085', 'mystery')
# ('tt0082089', 'suspenseful;atmospheric')
# ('tt0082158', 'inspiring')
# ('tt0082288', 'fantasy;violence')
# ('tt0082340', 'dark;violence;humor;action')
# ('tt0082348', 'violence')
# ('tt0082398', 'violence')
# ('tt0082418', 'cult;horror;violence;humor;suspenseful')
# ('tt0082432', 'atmospheric')
# ('tt0082449', 'horror')
# ('tt0082495', 'horror;violence;suspenseful')
# ('tt0082498', 'violence')
# ('tt0082509', 'comedy;violence')
# ('tt0082517', 'comedy')
# ('tt0082782', 'violence')
# ('tt0082846', 'romantic')
# ('tt0082869', 'atmospheric;violence')
# ('tt0082933', 'cult;violence;romantic')
# ('tt0082970', 'tragedy')
# ('tt0082971', 'comedy;mystery;violence;atmospheric;humor;action;romantic')
# ('tt0083511', 'comedy;suspenseful;violence;action')
# ('tt0083542', 'comedy;suspenseful;horror;violence;sadist')
# ('tt0083564', 'depressing')
# ('tt0083624', 'violence;horror')
# ('tt0083658', 'dark;boring;fantasy;mystery;dramatic;atmospheric;action;romantic')
# ('tt0083722', 'fantasy;mystery;dramatic;violence;romantic')
# ('tt0083767', 'comedy;dark;horror;violence')
# ('tt0083806', 'horror')
# ('tt0083929', 'romantic')
# ('tt0083943', 'suspenseful;violence')
# ('tt0083944', 'suspenseful;cult;violence;dramatic;action;tragedy;sadist')
# ('tt0084021', 'romantic')
# ('tt0084112', 'suspenseful;violence;sadist')
# ('tt0084370', 'action')
# ('tt0084503', 'dark;depressing;dramatic;violence;romantic')
# ('tt0084516', 'mystery;horror;suspenseful')
# ('tt0084602', 'comedy;bleak;violence;romantic')
# ('tt0084707', 'tragedy;sadist')
# ('tt0084777', 'violence;horror')
# ('tt0084805', 'romantic')
# ('tt0085255', 'action')
# ('tt0085636', 'horror')
# ('tt0085672', 'violence')
# ('tt0085701', 'paranormal;atmospheric')
# ('tt0085724', 'violence;romantic')
# ('tt0085811', 'action;romantic;fantasy')
# ('tt0085995', 'comedy')
# ('tt0086154', 'murder')
# ('tt0086190', 'fantasy;dramatic;violence;action;tragedy')
# ('tt0086200', 'prank')
# ('tt0086250', 'dramatic;violence;atmospheric;action;romantic;sadist')
# ('tt0086320', 'horror;violence')
# ('tt0086383', 'revenge;violence;humor;romantic')
# ('tt0086425', 'romantic;suspenseful;sentimental')
# ('tt0086508', 'comedy;violence;tragedy')
# ('tt0086525', 'violence')
# ('tt0086541', 'dark;suspenseful;mystery;violence;satire;sci-fi')
# ('tt0086879', 'dramatic;humor;tragedy;sentimental')
# ('tt0086960', 'comedy;violence;humor;action')
# ('tt0086973', 'romantic')
# ('tt0087050', 'violence;romantic')
# ('tt0087332', 'comedy;fantasy;mystery;humor;action')
# ('tt0087363', 'horror;comedy')
# ('tt0087469', 'mystery;cult;violence;action;romantic;sadist')
# ('tt0087843', 'violence;atmospheric;sadist')
# ('tt0087884', 'depressing')
# ('tt0087909', 'mystery;suspenseful;horror;violence;psychedelic;sadist')
# ('tt0087985', 'violence')
# ('tt0087995', 'dark;comedy;violence')
# ('tt0088128', 'humor;depressing;romantic')
# ('tt0088161', 'romantic')
# ('tt0088172', 'comedy;suspenseful;boring;violence;home movie')
# ('tt0088206', 'violence;romantic')
# ('tt0088258', 'comedy;boring;humor')
# ('tt0088680', 'comedy;dark;psychedelic')
# ('tt0088708', 'comedy;violence;action')
# ('tt0088763', 'comedy;mystery;fantasy;clever;humor;romantic')
# ('tt0088846', 'comedy;dark;fantasy;atmospheric;satire;humor')
# ('tt0088889', 'sadist')
# ('tt0088944', 'suspenseful;violence;action')
# ('tt0089118', 'suspenseful;violence')
# ('tt0089122', 'violence')
# ('tt0089155', 'humor;comedy')
# ('tt0089175', 'violence')
# ('tt0089360', 'plot twist;romantic;suspenseful')
# ('tt0089393', 'comedy')
# ('tt0089421', 'action')
# ('tt0089457', 'fantasy;dramatic;violence;tragedy;romantic')
# ('tt0089469', 'dark;fantasy;action;romantic')
# ('tt0089489', 'humor;violence')
# ('tt0089530', 'violence;action')
# ('tt0089604', 'violence')
# ('tt0089643', 'romantic')
# ('tt0089755', 'dramatic;romantic')
# ('tt0089767', 'violence')
# ('tt0089791', 'mystery;humor')
# ('tt0089822', 'comedy;bleak;violence;comic')
# ('tt0089841', 'romantic;comedy')
# ('tt0089880', 'violence;humor;action')
# ('tt0089881', 'violence;atmospheric;tragedy;sentimental')
# ('tt0089893', 'action;violence;fantasy')
# ('tt0089901', 'comedy;violence;humor;sadist')
# ('tt0089913', 'violence')
# ('tt0089927', 'comedy;violence;action;tragedy')
# ('tt0089941', 'suspenseful;violence')
# ('tt0090022', 'violence')
# ('tt0090056', 'humor')
# ('tt0090060', 'romantic')
# ('tt0090098', 'comedy')
# ('tt0090142', 'comedy;romantic')
# ('tt0090180', 'violence')
# ('tt0090184', 'romantic')
# ('tt0090305', 'comedy')
# ('tt0090329', 'mystery;dramatic;violence;romantic;suspenseful')
# ('tt0090357', 'violence;action;romantic')
# ('tt0090555', 'humor')
# ('tt0090605', 'dark;violence;horror;atmospheric;action;tragedy;suspenseful')
# ('tt0090670', 'violence')
# ('tt0090683', 'violence')
# ('tt0090756', 'dark;mystery;violence;atmospheric')
# ('tt0090837', 'violence')
# ('tt0090856', 'comedy;humor')
# ('tt0090859', 'comedy;mystery;violence;humor;action')
# ('tt0091042', 'comedy')
# ('tt0091053', 'violence')
# ('tt0091083', 'sadist')
# ('tt0091187', 'humor;comedy;violence')
# ('tt0091203', 'comedy;fantasy;violence;romantic')
# ('tt0091217', 'inspiring')
# ('tt0091225', 'action')
# ('tt0091288', 'tragedy;sentimental')
# ('tt0091369', 'fantasy;humor')
# ('tt0091396', 'comedy;romantic')
# ('tt0091419', 'comedy;dark;romantic;sadist')
# ('tt0091474', 'dark;cult;violence;atmospheric;suspenseful;sadist')
# ('tt0091499', 'violence')
# ('tt0091538', 'romantic')
# ('tt0091613', 'tragedy;depressing')
# ('tt0091630', 'comedy;dark;horror;violence;tragedy')
# ('tt0091777', 'comedy')
# ('tt0091778', 'flashback')
# ('tt0091790', 'comedy;romantic')
# ('tt0091799', 'violence')
# ('tt0091828', 'violence;humor')
# ('tt0091829', 'violence')
# ('tt0091860', 'violence;romantic')
# ('tt0091877', 'comedy')
# ('tt0091983', 'comedy;violence')
# ('tt0092005', 'dramatic;suspenseful')
# ('tt0092007', 'comedy;boring')
# ('tt0092086', 'comedy;humor;comic')
# ('tt0092099', 'fantasy;action;humor;inspiring;romantic')
# ('tt0092494', 'cute')
# ('tt0092546', 'comedy')
# ('tt0092563', 'dark;mystery;cult;violence')
# ('tt0092585', 'violence;humor;comedy;suspenseful')
# ('tt0092618', 'violence')
# ('tt0092675', 'comedy;violence;humor')
# ('tt0092699', 'romantic')
# ('tt0092718', 'romantic')
# ('tt0092796', 'comedy;violence')
# ('tt0092857', 'violence')
# ('tt0092890', 'cute;romantic')
# ('tt0092906', 'comedy;violence')
# ('tt0092965', 'depressing')
# ('tt0092991', 'comedy;dark;horror;violence;atmospheric;humor;tragedy;suspenseful;sadist')
# ('tt0093011', 'violence')
# ('tt0093036', 'sadist')
# ('tt0093058', 'dark;dramatic;violence;action')
# ('tt0093105', 'violence;comedy')
# ('tt0093137', 'violence')
# ('tt0093148', 'comedy')
# ('tt0093171', 'humor')
# ('tt0093177', 'boring;cult;violence;horror;sadist')
# ('tt0093407', 'romantic')
# ('tt0093409', 'comedy;dramatic;violence;humor;action')
# ('tt0093507', 'murder;violence')
# ('tt0093509', 'atmospheric')
# ('tt0093565', 'romantic;humor;boring')
# ('tt0093605', 'comedy;dark;cult;violence;atmospheric;romantic;suspenseful;sadist')
# ('tt0093640', 'mystery;violence;suspenseful')
# ('tt0093748', 'comedy')
# ('tt0093756', 'violence;comedy;comic')
# ('tt0093777', 'comedy;good versus evil;romantic;suspenseful')
# ('tt0093818', 'boring;depressing')
# ('tt0093822', 'comedy;psychedelic;humor')
# ('tt0093870', 'comedy;violence;action;romantic')
# ('tt0093886', 'romantic')
# ('tt0093993', 'fantasy')
# ('tt0094012', 'comedy;humor')
# ('tt0094027', 'inspiring')
# ('tt0094138', 'violence')
# ('tt0094142', 'comedy')
# ('tt0094291', 'comedy;violence')
# ('tt0094336', 'comedy;boring;bleak;romantic')
# ('tt0094602', 'comedy;revenge;violence;suspenseful;sadist')
# ('tt0094612', 'violence;humor;action')
# ('tt0094625', 'anti war;violence;atmospheric;action;romantic;comic')
# ('tt0094673', 'violence')
# ('tt0094737', 'comedy;romantic')
# ('tt0094862', 'dark;mystery;cult;horror')
# ('tt0094894', 'violence')
# ('tt0094898', 'fantasy;comedy')
# ('tt0094947', 'tragedy;romantic')
# ('tt0094964', 'psychedelic;tragedy;sadist')
# ('tt0095016', 'comedy;mystery;violence;humor;action;suspenseful')
# ('tt0095174', 'suspenseful;violence')
# ('tt0095179', 'comedy;violence;sadist')
# ('tt0095271', 'horror;violence')
# ('tt0095294', 'violence;horror')
# ('tt0095484', 'horror;violence;sadist')
# ('tt0095583', 'cult;violence')
# ('tt0095631', 'comedy')
# ('tt0095687', 'comedy')
# ('tt0095882', 'comedy')
# ('tt0095889', 'insanity')
# ('tt0095925', 'flashback')
# ('tt0095953', 'dramatic;cute;comedy')
# ('tt0095956', 'action;violence')
# ('tt0095963', 'action;comedy;violence')
# ('tt0096061', 'comedy;romantic')
# ('tt0096244', 'romantic')
# ('tt0096256', 'violence;humor;action;suspenseful')
# ('tt0096320', 'comedy')
# ('tt0096446', 'fantasy;romantic;sadist')
# ('tt0096463', 'romantic;comedy')
# ('tt0096487', 'comedy;violence;humor')
# ('tt0096787', 'murder')
# ('tt0096874', 'comedy;mystery;fantasy;humor')
# ('tt0096895', 'comedy;dark;suspenseful;bleak;mystery;violence;atmospheric;action;tragedy')
# ('tt0096928', 'comedy;historical')
# ('tt0096933', 'boring;violence;romantic;suspenseful')
# ('tt0096969', 'dramatic;boring')
# ('tt0097044', 'romantic;fantasy')
# ('tt0097116', 'romantic')
# ('tt0097123', 'satire;romantic')
# ('tt0097138', 'action;violence')
# ('tt0097162', 'mystery;violence;atmospheric;suspenseful')
# ('tt0097165', 'dramatic;sentimental;inspiring')
# ('tt0097216', 'atmospheric;comedy;violence')
# ('tt0097239', 'dramatic;boring')
# ('tt0097240', 'romantic;violence')
# ('tt0097351', 'dramatic;fantasy;inspiring')
# ('tt0097366', 'humor')
# ('tt0097388', 'violence;horror')
# ('tt0097428', 'comedy;fantasy;humor;action')
# ('tt0097438', 'tragedy')
# ('tt0097441', 'inspiring;violence')
# ('tt0097481', 'violence;humor;comedy')
# ('tt0097493', 'comedy;dark;bleak')
# ('tt0097523', 'comedy;fantasy')
# ('tt0097550', 'violence')
# ('tt0097637', 'violence;comedy')
# ('tt0097728', 'humor')
# ('tt0097731', 'boring')
# ('tt0097733', 'comedy;violence;humor;action')
# ('tt0097737', 'suspenseful;violence')
# ('tt0097742', 'mystery;violence;tragedy;suspenseful;sadist')
# ('tt0097815', 'comedy;humor')
# ('tt0097858', 'comedy;dark;boring;violence;satire')
# ('tt0097889', 'comedy;violence')
# ('tt0097940', 'atmospheric;humor')
# ('tt0097967', 'violence')
# ('tt0098042', 'comedy')
# ('tt0098067', 'comedy')
# ('tt0098084', 'cult;violence;horror;suspenseful')
# ('tt0098105', 'comedy')
# ('tt0098206', 'suspenseful;violence;humor;romantic')
# ('tt0098258', 'romantic')
# ('tt0098273', 'mystery')
# ('tt0098309', 'comedy')
# ('tt0098384', 'humor;cute;sentimental')
# ('tt0098439', 'comedy;action;violence')
# ('tt0098536', 'comedy')
# ('tt0098546', 'satire')
# ('tt0098554', 'humor')
# ('tt0098575', 'tragedy;romantic')
# ('tt0098625', 'comedy')
# ('tt0098627', 'comedy')
# ('tt0098635', 'cute;romantic')
# ('tt0098645', 'comedy')
# ('tt0099005', 'comedy')
# ('tt0099012', 'romantic')
# ('tt0099052', 'horror;suspenseful;action;comedy')
# ('tt0099077', 'inspiring;violence;dramatic;sentimental')
# ('tt0099088', 'comedy;fantasy;humor')
# ('tt0099141', 'violence;comedy;action')
# ('tt0099160', 'violence')
# ('tt0099180', 'comedy;violence')
# ('tt0099253', 'comedy;violence')
# ('tt0099348', 'boring;dramatic;violence;romantic')
# ('tt0099365', 'comedy;bleak;violence;horror;romantic')
# ('tt0099422', 'violence;romantic')
# ('tt0099487', 'comedy;fantasy;dark;psychedelic;romantic')
# ('tt0099582', 'flashback')
# ('tt0099685', 'dark;comedy;dramatic;violence')
# ('tt0099726', 'action;romantic;tragedy')
# ('tt0099740', 'comedy;violence')
# ('tt0099776', 'romantic')
# ('tt0099785', 'comedy;violence;humor')
# ('tt0099800', 'romantic')
# ('tt0099864', 'dark;comedy;horror;sadist')
# ('tt0099871', 'violence;horror;insanity;tragedy')
# ('tt0099878', 'romantic')
# ('tt0099902', 'tragedy;sadist')
# ('tt0099938', 'comedy;fantasy;violence;cute;humor;romantic')
# ('tt0100029', 'comedy;violence;humor;tragedy')
# ('tt0100050', 'dramatic')
# ('tt0100114', 'comedy;violence;humor')
# ('tt0100133', 'comedy')
# ('tt0100140', 'dramatic;comedy;romantic')
# ('tt0100143', 'tragedy;violence')
# ('tt0100150', 'comedy;boring;dramatic;violence;atmospheric;romantic;suspenseful')
# ('tt0100157', 'mystery;dramatic;violence;horror;suspenseful;sadist')
# ('tt0100168', 'violence')
# ('tt0100211', 'horror')
# ('tt0100258', 'suspenseful;horror;violence')
# ('tt0100318', 'suspenseful')
# ('tt0100403', 'comedy;cult;violence;action;suspenseful')
# ('tt0100475', 'satire')
# ('tt0100502', 'violence;sci-fi')
# ('tt0100507', 'dramatic;action')
# ('tt0100680', 'romantic')
# ('tt0100813', 'violence;action')
# ('tt0101414', 'fantasy;cute;humor;romantic')
# ('tt0101540', 'suspenseful;mystery;violence;horror')
# ('tt0101635', 'romantic')
# ('tt0101669', 'comedy;mystery;violence;humor;romantic;suspenseful')
# ('tt0101700', 'comedy;dark;atmospheric;claustrophobic')
# ('tt0101745', 'comedy;boring')
# ('tt0101775', 'humor')
# ('tt0101898', 'romantic;sadist')
# ('tt0101917', 'comedy;horror;violence;psychedelic;sadist')
# ('tt0102005', 'comedy')
# ('tt0102034', 'comedy;violence;action')
# ('tt0102057', 'fantasy;violence;action')
# ('tt0102059', 'comedy;humor')
# ('tt0102103', 'violence')
# ('tt0102138', 'boring')
# ('tt0102202', 'violence')
# ('tt0102316', 'depressing')
# ('tt0102492', 'dramatic;sentimental')
# ('tt0102511', 'comedy;humor')
# ('tt0102536', 'comedy;humor')
# ('tt0102558', 'comedy')
# ('tt0102592', 'violence;atmospheric;suspenseful')
# ('tt0102598', 'romantic')
# ('tt0102685', 'murder;violence')
# ('tt0102728', 'violence')
# ('tt0102744', 'violence')
# ('tt0102782', 'boring')
# ('tt0102798', 'comedy;atmospheric;action;romantic')
# ('tt0102802', 'boring')
# ('tt0102951', 'comedy')
# ('tt0102975', 'mystery')
# ('tt0103003', 'comic')
# ('tt0103060', 'humor;violence')
# ('tt0103064', 'mystery;alternate reality;violence;humor;action;romantic;suspenseful')
# ('tt0103074', 'dramatic;violence;action;tragedy')
# ('tt0103112', 'violence')
# ('tt0103241', 'humor')
# ('tt0103594', 'dramatic;boring')
# ('tt0103596', 'dark')
# ('tt0103639', 'comedy;action;fantasy')
# ('tt0103644', 'dark;boring;allegory;violence;suspenseful')
# ('tt0103671', 'violence')
# ('tt0103772', 'suspenseful;mystery;violence;romantic;sadist')
# ('tt0103776', 'dark;fantasy;mystery;violence;action;comic;tragedy')
# ('tt0103786', 'comedy')
# ('tt0103843', 'violence;romantic')
# ('tt0103874', 'violence;horror;romantic')
# ('tt0103893', 'comedy;murder')
# ('tt0103924', 'comedy')
# ('tt0103939', 'dramatic')
# ('tt0103956', 'violence;comedy;dark')
# ('tt0104070', 'comedy;dark;revenge')
# ('tt0104231', 'romantic')
# ('tt0104346', 'inspiring')
# ('tt0104348', 'boring')
# ('tt0104409', 'horror;violence')
# ('tt0104427', 'depressing')
# ('tt0104438', 'comedy')
# ('tt0104454', 'romantic;boring')
# ('tt0104507', 'romantic;atmospheric;sentimental')
# ('tt0104550', 'romantic')
# ('tt0104573', 'comedy;violence')
# ('tt0104647', 'romantic')
# ('tt0104695', 'romantic')
# ('tt0104714', 'comedy;violence;action')
# ('tt0104756', 'inspiring;romantic')
# ('tt0104779', 'comedy;sadist')
# ('tt0104797', 'violence')
# ('tt0104952', 'comedy;mystery')
# ('tt0105046', 'tragedy;dramatic;depressing')
# ('tt0105104', 'violence;humor;action;suspenseful')
# ('tt0105112', 'suspenseful;mystery;violence')
# ('tt0105130', 'romantic')
# ('tt0105217', 'mystery;dramatic')
# ('tt0105226', 'comedy')
# ('tt0105236', 'comedy;dark;boring;suspenseful;mystery;dramatic;violence;sadist;humor;tragedy')
# ('tt0105323', 'dramatic;atmospheric')
# ('tt0105402', 'violence')
# ('tt0105414', 'mystery;violence;suspenseful')
# ('tt0105428', 'horror;dark;violence')
# ('tt0105435', 'comedy;suspenseful;intrigue;entertaining')
# ('tt0105488', 'romantic')
# ('tt0105629', 'psychedelic')
# ('tt0105690', 'comedy;violence;humor;action;suspenseful')
# ('tt0105695', 'suspenseful;bleak;sadist')
# ('tt0105698', 'violence;action')
# ('tt0105699', 'suspenseful')
# ('tt0105793', 'comedy;humor')
# ('tt0105812', 'comedy;humor')
# ('tt0105813', 'comedy;violence;romantic;suspenseful')
# ('tt0106220', 'comedy;horror;romantic')
# ('tt0106273', 'tragedy')
# ('tt0106308', 'comedy;dark;boring;fantasy;violence;horror;humor;action')
# ('tt0106364', 'comedy;cult;violence;psychedelic;romantic;tragedy;sadist')
# ('tt0106375', 'romantic;comedy')
# ('tt0106519', 'violence;romantic')
# ('tt0106521', 'violence')
# ('tt0106582', 'mystery;suspenseful;violence;action;tragedy')
# ('tt0106611', 'inspiring;comedy;feel-good')
# ('tt0106673', 'romantic;fantasy')
# ('tt0106677', 'psychedelic')
# ('tt0106697', 'comedy;violence;humor;action;sadist')
# ('tt0106770', 'dramatic;violence;romantic')
# ('tt0106856', 'comedy;violence;tragedy')
# ('tt0106873', 'romantic')
# ('tt0106881', 'boring')
# ('tt0106950', 'violence')
# ('tt0107004', 'violence')
# ('tt0107048', 'comedy;boring;fantasy;cute;feel-good;humor;romantic')
# ('tt0107050', 'comedy')
# ('tt0107076', 'comedy;violence;action;sadist')
# ('tt0107120', 'horror;romantic')
# ('tt0107144', 'comedy;humor;comic')
# ('tt0107148', 'fantasy')
# ('tt0107206', 'suspenseful;mystery;violence;humor;action;romantic')
# ('tt0107207', 'tragedy;dramatic;violence')
# ('tt0107286', 'violence')
# ('tt0107290', 'mystery;dramatic;violence;horror;action;humor;suspenseful')
# ('tt0107315', 'comedy')
# ('tt0107387', 'horror;suspenseful;comedy;violence')
# ('tt0107473', 'romantic')
# ('tt0107497', 'murder')
# ('tt0107507', 'comedy;mystery')
# ('tt0107554', 'comedy;suspenseful;bleak;violence;romantic')
# ('tt0107614', 'comedy;bleak;dramatic;suspenseful')
# ('tt0107665', 'violence')
# ('tt0107750', 'violence')
# ('tt0107818', 'dramatic;romantic')
# ('tt0107843', 'suspenseful')
# ('tt0107977', 'comedy;action;humor;comic')
# ('tt0107983', 'comedy;suspenseful;violence;tragedy;sadist')
# ('tt0108002', 'inspiring')
# ('tt0108122', 'comedy;humor')
# ('tt0108149', 'humor')
# ('tt0108160', 'dramatic;romantic;boring;comedy')
# ('tt0108162', 'suspenseful;mystery')
# ('tt0108171', 'suspenseful;violence')
# ('tt0108174', 'comedy;psychedelic;romantic')
# ('tt0108308', 'violence')
# ('tt0108330', 'violence')
# ('tt0108358', 'suspenseful;violence')
# ('tt0108399', 'comedy;violence;action;romantic')
# ('tt0108550', 'tragedy;boring;depressing')
# ('tt0109021', 'tragedy;romantic')
# ('tt0109035', 'violence')
# ('tt0109040', 'comedy;bleak;humor;action')
# ('tt0109068', 'comedy')
# ('tt0109254', 'comedy;violence;comic')
# ('tt0109297', 'mystery')
# ('tt0109303', 'suspenseful;violence;action')
# ('tt0109439', 'violence')
# ('tt0109579', 'suspenseful')
# ('tt0109758', 'romantic;comedy;sadist')
# ('tt0109781', 'dark')
# ('tt0109830', 'comedy;dramatic;cute;psychedelic;humor;action;feel-good;inspiring;romantic;sentimental')
# ('tt0109831', 'comedy;romantic')
# ('tt0109836', 'violence')
# ('tt0109842', 'tragedy;violence')
# ('tt0110005', 'fantasy;boring;violence;psychedelic;romantic')
# ('tt0110027', 'action;violence')
# ('tt0110148', 'comedy;fantasy;dramatic;violence;horror;atmospheric')
# ('tt0110167', 'romantic;comedy;feel-good')
# ('tt0110186', 'violence')
# ('tt0110265', 'violence')
# ('tt0110322', 'dramatic;romantic;tragedy;sentimental')
# ('tt0110329', 'violence')
# ('tt0110367', 'dramatic;romantic')
# ('tt0110395', 'violence')
# ('tt0110443', 'comedy;humor')
# ('tt0110478', 'mystery;comedy')
# ('tt0110598', 'comedy;humor')
# ('tt0110604', 'comedy;violence')
# ('tt0110622', 'comedy;boring;humor')
# ('tt0110632', 'comedy;cult;violence;satire;romantic;sadist')
# ('tt0110882', 'violence')
# ('tt0110912', 'comedy;action;suspenseful;clever;atmospheric;dark;mystery;dramatic;violence;humor')
# ('tt0110939', 'mystery')
# ('tt0110950', 'romantic')
# ('tt0111048', 'comedy;violence;tragedy;romantic')
# ('tt0111127', 'comedy;violence')
# ('tt0111149', 'comedy;dark;violence;atmospheric;romantic')
# ('tt0111257', 'comedy;boring;mystery;violence;humor;action;romantic;suspenseful')
# ('tt0111282', 'violence;suspenseful;action;atmospheric')
# ('tt0111323', 'comedy;suspenseful;violence;humor')
# ('tt0111419', 'fantasy')
# ('tt0111438', 'humor;violence')
# ('tt0111477', 'bleak')
# ('tt0111503', 'comedy;mystery;violence;action')
# ('tt0111732', 'feel-good')
# ('tt0111742', 'comedy;satire')
# ('tt0111756', 'violence')
# ('tt0112281', 'humor;comedy')
# ('tt0112302', 'suspenseful;violence')
# ('tt0112362', 'romantic')
# ('tt0112365', 'romantic')
# ('tt0112384', 'mystery;boring;dramatic;suspenseful')
# ('tt0112401', 'suspenseful;violence;romantic;sadist')
# ('tt0112443', 'mystery;action')
# ('tt0112462', 'comedy;violence;atmospheric;action')
# ('tt0112471', 'romantic;boring')
# ('tt0112508', 'comedy')
# ('tt0112536', 'violence')
# ('tt0112537', 'romantic')
# ('tt0112573', 'dramatic;violence;action;romantic;inspiring')
# ('tt0112641', 'comedy;violence;sadist')
# ('tt0112642', 'psychedelic;sentimental')
# ('tt0112681', 'mystery')
# ('tt0112688', 'violence')
# ('tt0112697', 'comedy;romantic')
# ('tt0112722', 'mystery;violence;horror;suspenseful')
# ('tt0112740', 'suspenseful;comedy')
# ('tt0112792', 'inspiring')
# ('tt0112851', 'comedy;mystery;violence;humor;action;romantic')
# ('tt0112857', 'violence;atmospheric;suspenseful')
# ('tt0112896', 'romantic')
# ('tt0113071', 'romantic')
# ('tt0113097', 'boring')
# ('tt0113114', 'romantic')
# ('tt0113161', 'comedy;violence')
# ('tt0113189', 'dark;violence;action;sadist')
# ('tt0113228', 'comedy')
# ('tt0113243', 'boring;action')
# ('tt0113253', 'horror;violence')
# ('tt0113277', 'suspenseful;bleak;violence;atmospheric;action')
# ('tt0113303', 'horror;violence;sadist')
# ('tt0113305', 'violence')
# ('tt0113321', 'boring')
# ('tt0113347', 'romantic')
# ('tt0113409', 'comedy;fantasy;cult;violence;psychedelic;suspenseful')
# ('tt0113481', 'violence')
# ('tt0113492', 'comedy;good versus evil;humor;romantic')
# ('tt0113540', 'tragedy;violence')
# ('tt0113552', 'violence')
# ('tt0113617', 'comedy')
# ('tt0113627', 'dark;depressing;dramatic;atmospheric;tragedy;romantic')
# ('tt0113677', 'romantic')
# ('tt0113690', 'violence')
# ('tt0113729', 'romantic')
# ('tt0113749', 'comedy;humor;romantic;comic')
# ('tt0113820', 'action;violence')
# ('tt0113862', 'inspiring;romantic;feel-good')
# ('tt0113967', 'dark;violence')
# ('tt0113986', 'comedy;romantic;humor')
# ('tt0113987', 'dramatic')
# ('tt0114069', 'suspenseful;romantic')
# ('tt0114148', 'tragedy;romantic')
# ('tt0114168', 'romantic')
# ('tt0114279', 'tragedy')
# ('tt0114287', 'violence;atmospheric;action;romantic;suspenseful')
# ('tt0114319', 'dramatic;romantic;fantasy')
# ('tt0114367', 'horror;suspenseful')
# ('tt0114436', 'boring')
# ('tt0114550', 'violence')
# ('tt0114558', 'dark;cult;violence;sci-fi')
# ('tt0114576', 'suspenseful;action;violence')
# ('tt0114594', 'comedy;bleak;sadist')
# ('tt0114609', 'violence')
# ('tt0114614', 'humor;violence')
# ('tt0114660', 'comedy;violence')
# ('tt0114694', 'comedy;humor')
# ('tt0114702', 'violence;romantic;sadist')
# ('tt0114709', 'comedy;fantasy;cute;violence;humor')
# ('tt0114746', 'comedy;dark;depressing;mystery;dramatic;violence;atmospheric;alternate history')
# ('tt0114781', 'comedy;action;violence')
# ('tt0114787', 'comedy;romantic')
# ('tt0114852', 'violence')
# ('tt0114857', 'violence;sadist')
# ('tt0114906', 'comedy;depressing')
# ('tt0114924', 'cute;boring;romantic;feel-good')
# ('tt0114938', 'flashback')
# ('tt0115438', 'comedy;suspenseful;violence')
# ('tt0115624', 'flashback')
# ('tt0115639', 'violence;humor;atmospheric;romantic')
# ('tt0115640', 'feel-good')
# ('tt0115641', 'comedy')
# ('tt0115644', 'romantic;fantasy')
# ('tt0115710', 'romantic')
# ('tt0115714', 'violence')
# ('tt0115734', 'humor;romantic')
# ('tt0115744', 'romantic')
# ('tt0115886', 'comedy;violence')
# ('tt0115906', 'dark')
# ('tt0115956', 'violence')
# ('tt0115964', 'mystery;violence;sadist')
# ('tt0116126', 'comedy;humor')
# ('tt0116147', 'suspenseful;violence')
# ('tt0116213', 'violence;action')
# ('tt0116225', 'mystery;violence;humor')
# ('tt0116253', 'mystery;suspenseful;violence')
# ('tt0116282', 'comedy;dark;boring;bleak;violence;entertaining')
# ('tt0116287', 'violence')
# ('tt0116289', 'comedy')
# ('tt0116311', 'violence')
# ('tt0116329', 'tragedy;inspiring')
# ('tt0116361', 'comedy;fantasy;violence;romantic')
# ('tt0116367', 'comedy;violence;horror;humor;action')
# ('tt0116483', 'comedy;humor')
# ('tt0116488', 'comedy;violence;romantic')
# ('tt0116514', 'violence;horror;sadist')
# ('tt0116531', 'comedy')
# ('tt0116571', 'romantic')
# ('tt0116607', 'violence')
# ('tt0116629', 'mystery;humor;action;tragedy;suspenseful')
# ('tt0116683', 'fantasy;sadist')
# ('tt0116695', 'comedy;humor;romantic')
# ('tt0116705', 'comic')
# ('tt0116722', 'tragedy')
# 168
# ['tt0045888', 'tt0046672', 'tt0047849', 'tt0050419', 'tt0052918', 'tt0052948', 'tt0054494', 'tt0055257', 'tt0055928', 'tt0057076', 'tt0057197', 'tt0058777', 'tt0059017', 'tt0059125', 'tt0064603', 'tt0065738', 'tt0066995', 'tt0067065', 'tt0067093', 'tt0068240', 'tt0073018', 'tt0075261', 'tt0076009', 'tt0076141', 'tt0076716', 'tt0077235', 'tt0077572', 'tt0077578', 'tt0077663', 'tt0078158', 'tt0079540', 'tt0080319', 'tt0080391', 'tt0080421', 'tt0080745', 'tt0081207', 'tt0081375', 'tt0081748', 'tt0082009', 'tt0082220', 'tt0082727', 'tt0082766', 'tt0083284', 'tt0083530', 'tt0084522', 'tt0084786', 'tt0084854', 'tt0085204', 'tt0085271', 'tt0085276', 'tt0085382', 'tt0085475', 'tt0085750', 'tt0085809', 'tt0085970', 'tt0085980', 'tt0086034', 'tt0086143', 'tt0086361', 'tt0086450', 'tt0086567', 'tt0086859', 'tt0087032', 'tt0087065', 'tt0087277', 'tt0087507', 'tt0087747', 'tt0087921', 'tt0088000', 'tt0088170', 'tt0088850', 'tt0089015', 'tt0089114', 'tt0089424', 'tt0089504', 'tt0089886', 'tt0090567', 'tt0090660', 'tt0090888', 'tt0091278', 'tt0091374', 'tt0091653', 'tt0091680', 'tt0091767', 'tt0091954', 'tt0091991', 'tt0092608', 'tt0093164', 'tt0093200', 'tt0093220', 'tt0093223', 'tt0093260', 'tt0093476', 'tt0093489', 'tt0093638', 'tt0093692', 'tt0093857', 'tt0094008', 'tt0094155', 'tt0094792', 'tt0094799', 'tt0094933', 'tt0095652', 'tt0095655', 'tt0095863', 'tt0096142', 'tt0096378', 'tt0096866', 'tt0097236', 'tt0098382', 'tt0099329', 'tt0099512', 'tt0100129', 'tt0100201', 'tt0100280', 'tt0100436', 'tt0101393', 'tt0101452', 'tt0101757', 'tt0102175', 'tt0102469', 'tt0102945', 'tt0103850', 'tt0104009', 'tt0104265', 'tt0104466', 'tt0104740', 'tt0104897', 'tt0104990', 'tt0105156', 'tt0105211', 'tt0105391', 'tt0106266', 'tt0106598', 'tt0106701', 'tt0106926', 'tt0107247', 'tt0107756', 'tt0108238', 'tt0108526', 'tt0109190', 'tt0109370', 'tt0109484', 'tt0110097', 'tt0110216', 'tt0110613', 'tt0110706', 'tt0110759', 'tt0111280', 'tt0112950', 'tt0113089', 'tt0113443', 'tt0113501', 'tt0113636', 'tt0113870', 'tt0113896', 'tt0114011', 'tt0114272', 'tt0114323', 'tt0114671', 'tt0114720', 'tt0114885', 'tt0114898', 'tt0116130', 'tt0116259', 'tt0116493', 'tt0116508', 'tt0116594']

# %%
print(len(item_list))
print(len(tag_str))
print(len(item_list_ext_id))
# Out:
# 987
# 987
# 819

# %%
# 987 STFT 파일 중 태그 정리하면서 168개 제외한 사진 복사하기
import os
stft_987_dir = r"E:\NRF_2022\MDPI\Extracted_Data\new_stft_2024_all"

path = "./"
stft_987_flist = os.listdir(stft_987_dir)
stft_987_fnames=[]

for f_n in stft_987_flist:
    path, ext = os.path.splitext(f_n)
    stft_987_fnames.append(path)
print ("stft_987_flist: {}".format(stft_987_fnames))
print(len(stft_987_fnames))
# Out:
# stft_987_flist: ['tt0023427', 'tt0029583', 'tt0031381', 'tt0032910', 'tt0034492', 'tt0035896', 'tt0040746', 'tt0041716', 'tt0043274', 'tt0043379', 'tt0044926', 'tt0045125', 'tt0045152', 'tt0045810', 'tt0045888', 'tt0045963', 'tt0046183', 'tt0046303', 'tt0046672', 'tt0046912', 'tt0047396', 'tt0047472', 'tt0047673', 'tt0047834', 'tt0047849', 'tt0048545', 'tt0048728', 'tt0049223', 'tt0049261', 'tt0049966', 'tt0050419', 'tt0051459', 'tt0051554', 'tt0051658', 'tt0052357', 'tt0052905', 'tt0052918', 'tt0052948', 'tt0053172', 'tt0053221', 'tt0054047', 'tt0054195', 'tt0054331', 'tt0054494', 'tt0054698', 'tt0054847', 'tt0055257', 'tt0055304', 'tt0055471', 'tt0055614', 'tt0055928', 'tt0056172', 'tt0056264', 'tt0056923', 'tt0057076', 'tt0057197', 'tt0058150', 'tt0058329', 'tt0058385', 'tt0058571', 'tt0058672', 'tt0058777', 'tt0059017', 'tt0059113', 'tt0059125', 'tt0059800', 'tt0060345', 'tt0063442', 'tt0063518', 'tt0063522', 'tt0064276', 'tt0064603', 'tt0064665', 'tt0064782', 'tt0065054', 'tt0065063', 'tt0065088', 'tt0065112', 'tt0065134', 'tt0065207', 'tt0065377', 'tt0065462', 'tt0065724', 'tt0065738', 'tt0066206', 'tt0066214', 'tt0066434', 'tt0066808', 'tt0066995', 'tt0066999', 'tt0067023', 'tt0067065', 'tt0067093', 'tt0067185', 'tt0067309', 'tt0067741', 'tt0067756', 'tt0067800', 'tt0067959', 'tt0067992', 'tt0068240', 'tt0068327', 'tt0068473', 'tt0068555', 'tt0068611', 'tt0068699', 'tt0068762', 'tt0069097', 'tt0069280', 'tt0069281', 'tt0069704', 'tt0069762', 'tt0069865', 'tt0069995', 'tt0070016', 'tt0070034', 'tt0070239', 'tt0070328', 'tt0070355', 'tt0070379', 'tt0070511', 'tt0070608', 'tt0070666', 'tt0070698', 'tt0071110', 'tt0071129', 'tt0071230', 'tt0071315', 'tt0071402', 'tt0071455', 'tt0071569', 'tt0071853', 'tt0071994', 'tt0072288', 'tt0072684', 'tt0072890', 'tt0073018', 'tt0073195', 'tt0073440', 'tt0073486', 'tt0073540', 'tt0073812', 'tt0074119', 'tt0074256', 'tt0074285', 'tt0074455', 'tt0074512', 'tt0074860', 'tt0074937', 'tt0074958', 'tt0074991', 'tt0075222', 'tt0075223', 'tt0075261', 'tt0075314', 'tt0075648', 'tt0075860', 'tt0076009', 'tt0076141', 'tt0076451', 'tt0076538', 'tt0076578', 'tt0076636', 'tt0076716', 'tt0076929', 'tt0077235', 'tt0077394', 'tt0077402', 'tt0077405', 'tt0077413', 'tt0077523', 'tt0077572', 'tt0077578', 'tt0077663', 'tt0077742', 'tt0077745', 'tt0077975', 'tt0078087', 'tt0078158', 'tt0078480', 'tt0078721', 'tt0078723', 'tt0078748', 'tt0078754', 'tt0078788', 'tt0078902', 'tt0079116', 'tt0079261', 'tt0079285', 'tt0079417', 'tt0079489', 'tt0079501', 'tt0079522', 'tt0079540', 'tt0079574', 'tt0079817', 'tt0080025', 'tt0080031', 'tt0080319', 'tt0080339', 'tt0080360', 'tt0080365', 'tt0080377', 'tt0080391', 'tt0080421', 'tt0080472', 'tt0080474', 'tt0080487', 'tt0080661', 'tt0080684', 'tt0080745', 'tt0080761', 'tt0080923', 'tt0080979', 'tt0081114', 'tt0081207', 'tt0081283', 'tt0081375', 'tt0081383', 'tt0081455', 'tt0081505', 'tt0081534', 'tt0081573', 'tt0081696', 'tt0081748', 'tt0082009', 'tt0082031', 'tt0082085', 'tt0082089', 'tt0082158', 'tt0082220', 'tt0082288', 'tt0082340', 'tt0082348', 'tt0082398', 'tt0082418', 'tt0082432', 'tt0082449', 'tt0082495', 'tt0082498', 'tt0082509', 'tt0082517', 'tt0082727', 'tt0082766', 'tt0082782', 'tt0082846', 'tt0082869', 'tt0082933', 'tt0082970', 'tt0082971', 'tt0083284', 'tt0083511', 'tt0083530', 'tt0083542', 'tt0083564', 'tt0083624', 'tt0083658', 'tt0083722', 'tt0083767', 'tt0083806', 'tt0083929', 'tt0083943', 'tt0083944', 'tt0084021', 'tt0084112', 'tt0084370', 'tt0084503', 'tt0084516', 'tt0084522', 'tt0084602', 'tt0084707', 'tt0084777', 'tt0084786', 'tt0084805', 'tt0084854', 'tt0085204', 'tt0085255', 'tt0085271', 'tt0085276', 'tt0085382', 'tt0085475', 'tt0085636', 'tt0085672', 'tt0085701', 'tt0085724', 'tt0085750', 'tt0085809', 'tt0085811', 'tt0085970', 'tt0085980', 'tt0085995', 'tt0086034', 'tt0086143', 'tt0086154', 'tt0086190', 'tt0086200', 'tt0086250', 'tt0086320', 'tt0086361', 'tt0086383', 'tt0086425', 'tt0086450', 'tt0086508', 'tt0086525', 'tt0086541', 'tt0086567', 'tt00 ...
# 987

# %%
import shutil

sc_dir = stft_987_dir
dst_dir  = r"E:\NRF_2022\MDPI\Extracted_Data\new_stft_2024_mood_extracted2"
f_cnt=0
for tf_n in stft_987_fnames:
    sc_file=""
    dst_file=""
    if tf_n in rmove_item_list: # 제거 목록에 포함되면 PASS
        pass
    else:
        f_cnt+=1
        sc_file = sc_dir + '\\' +tf_n +'.png'
        dst_file = dst_dir + '\\'+ tf_n +'.png'
        
        shutil.copyfile(sc_file, dst_file) # 복사
print(f"복사된 파일은 {f_cnt}개 입니다.")
# Out:
# 복사된 파일은 819개 입니다.

# %%
# ---

# %%
# import os
# t_source = r"E:\NRF_2022\MDPI\Extracted_Data\new_stft_935_split_cp\train"

# path = "./"
# file_list = os.listdir(t_source)
# train_file_names=[]

# for f_n in file_list:
#     path, ext = os.path.splitext(f_n)
#     train_file_names.append(path)
# print ("train_file_list: {}".format(train_file_names))
# print(len(train_file_names))

# %%
# test_source = r"E:\NRF_2022\MDPI\Extracted_Data\new_stft_935_split_cp\test"

# path = "./"
# file_list2 = os.listdir(test_source)
# test_file_names=[]

# for f_n in file_list2:
#     path, ext = os.path.splitext(f_n)
#     test_file_names.append(path)
# print ("test_file_names: {}".format(test_file_names))
# print(len(test_file_names))

# %%
# print(len(train_file_names))
# print(len(rmove_item_list))

# %%
# sc_dir3 = r"E:\NRF_2022\\MDPI\Extracted_Data\new_stft_935_split_cp\val"
# dst_dir3  = r"E:\NRF_2022\MDPI\Extracted_Data\new_stft_935_split2\val"

# for v_n in val_file_names:
#     sc_file=""
#     dst_file=""
#     if v_n not in rmove_item_list: # 제거 목록에 없으면 
#         sc_file = sc_dir3 + '\\' +v_n +'.png'
#         dst_file = dst_dir3 + '\\'+ v_n +'.png'
        
#         shutil.copyfile(sc_file, dst_file) # 복사

# %%
# df4.columns=['imdb_id', 'tags']
# print(df4)

# %%
df_mood = pd.DataFrame([ x for x in zip(item_list_ext_id,item_list_ext_tag)])
df_mood.columns=['imdb_id', 'tags']
print(df_mood)
# Out:
#        imdb_id                                      tags
# 0    tt0023427                                  violence
# 1    tt0029583                     fantasy;cute;romantic
# 2    tt0031381                           romantic;boring
# 3    tt0032910                              cute;fantasy
# 4    tt0034492                                      cute
# ..         ...                                       ...
# 814  tt0116629  mystery;humor;action;tragedy;suspenseful
# 815  tt0116683                            fantasy;sadist
# 816  tt0116695                     comedy;humor;romantic
# 817  tt0116705                                     comic
# 818  tt0116722                                   tragedy
#
# [819 rows x 2 columns]

# %%
print(item_list_ext_tag)
# Out:
# ['violence', 'fantasy;cute;romantic', 'romantic;boring', 'cute;fantasy', 'cute', 'violence', 'atmospheric;suspenseful', 'romantic', 'fantasy;cute', 'violence;action', 'romantic', 'action', 'comedy;boring;romantic', 'romantic', 'romantic', 'fantasy;action', 'violence', 'suspenseful', 'mystery;suspenseful;horror', 'romantic', 'romantic', 'murder', 'violence;romantic', 'atmospheric', 'comedy;psychedelic;suspenseful', 'romantic;depressing', 'romantic', 'sentimental', 'violence;suspenseful', 'romantic', 'mystery;atmospheric;romantic', 'atmospheric', 'romantic;comedy', 'suspenseful;humor', 'violence', 'romantic', 'tragedy;romantic;violence', 'humor;romantic;sentimental', 'violence', 'murder', 'romantic', 'tragedy;romantic', 'violence;atmospheric', 'action', 'romantic;humor', 'suspenseful;action;humor', 'romantic', 'romantic', 'romantic', 'suspenseful', 'atmospheric;romantic', 'humor;suspenseful', 'fantasy;humor', 'dramatic;violence;suspenseful', 'action;romantic;tragedy', 'horror;atmospheric;suspenseful', 'comedy;dark;atmospheric;humor', 'tragedy;humor', 'comedy', 'tragedy', 'comedy', 'depressing', 'suspenseful', 'violence', 'violence;romantic', 'suspenseful', 'violence;action;suspenseful', 'romantic', 'violence;boring', 'mystery;violence;atmospheric', 'suspenseful;cult;romantic', 'comedy', 'dark;suspenseful;realism;violence;sadist', 'mystery;comedy;suspenseful', 'comedy;dark;cute;humor', 'mystery;sadist', 'violence;atmospheric;suspenseful', 'comedy;atmospheric;inspiring', 'suspenseful;violence;sadist', 'mystery', 'boring;fantasy;cute', 'romantic;depressing', 'mystery;cult;violence;suspenseful', 'humor', 'horror;suspenseful;sadist', 'dark;suspenseful;mystery;bleak;violence;revenge', 'bleak;atmospheric', 'romantic', 'boring;absurd', 'mystery;revenge;suspenseful', 'romantic', 'bleak;atmospheric;violence', 'suspenseful', 'atmospheric;suspenseful', 'romantic;cute;sentimental', 'suspenseful;violence', 'boring', 'murder;violence', 'violence', 'comedy;violence', 'violence;boring;romantic', 'action', 'dark;violence;atmospheric;romantic', 'cult;claustrophobic', 'suspenseful', 'humor', 'comedy;absurd;comic', 'comedy;dark;depressing;mystery;bleak;violence;atmospheric;humor;suspenseful', 'murder;violence', 'comedy;suspenseful;revenge', 'action', 'comedy;violence;humor', 'dark;comedy;cult;violence;tragedy', 'violence;comedy', 'boring;atmospheric', 'comedy;atmospheric', 'horror;suspenseful;violence', 'tragedy;humor;atmospheric', 'depressing;dramatic;violence;sadist;sentimental', 'mystery;boring', 'humor;boring', 'inspiring;suspenseful;mystery;dramatic', 'depressing;comic', 'comedy;fantasy;suspenseful;dark;violence;horror;atmospheric;romantic;tragedy;sadist', 'horror;violence', 'suspenseful', 'suspenseful;violence;horror', 'mystery', 'comedy;dramatic;atmospheric;humor', 'violence', 'comedy', 'comedy;violence', 'dark;boring;violence;atmospheric;romantic', 'suspenseful', 'mystery;dramatic;humor', 'romantic', 'action;boring', 'boring', 'suspenseful;comedy', 'fantasy;violence;absurd;romantic', 'violence', 'comedy;suspenseful;horror;violence;action;entertaining;sadist', 'tragedy;boring;atmospheric', 'mystery', 'comedy;violence', 'depressing', 'horror;violence;humor', 'comedy;entertaining', 'tragedy;comedy;violence', 'violence;atmospheric;romantic', 'romantic', 'satire', 'dark;boring;mystery;violence;horror;atmospheric;action;suspenseful', 'tragedy;comedy', 'dark;boring;violence;dramatic;action;suspenseful', 'inspiring', 'suspenseful;violence', 'romantic', 'violence', 'dramatic', 'romantic', 'suspenseful;violence;action;tragedy', 'comedy;humor;romantic', 'suspenseful', 'violence;romantic', 'violence;romantic', 'violence', 'comedy;absurd;humor;romantic', 'violence;romantic;suspenseful', 'sadist', 'violence', 'violence;comic', 'violence', 'comedy;violence;humor', 'mystery;violence;suspenseful;sadist', 'dark;fantasy;mystery;violence;action;tragedy', 'suspenseful;murder;boring;horror;violence;sadist', 'dark;violence;horror;atmospheric;suspenseful;sadist', ' ...

# %%
item_list_ext_tag_=[]
item_list_ext_tag_list=[]
for i in range(len(item_list_ext_tag)):
    item_list_ext_tag_=item_list_ext_tag[i].split(';')
    item_list_ext_tag_list.append(item_list_ext_tag_)
print(item_list_ext_tag_list)
# Out:
# [['violence'], ['fantasy', 'cute', 'romantic'], ['romantic', 'boring'], ['cute', 'fantasy'], ['cute'], ['violence'], ['atmospheric', 'suspenseful'], ['romantic'], ['fantasy', 'cute'], ['violence', 'action'], ['romantic'], ['action'], ['comedy', 'boring', 'romantic'], ['romantic'], ['romantic'], ['fantasy', 'action'], ['violence'], ['suspenseful'], ['mystery', 'suspenseful', 'horror'], ['romantic'], ['romantic'], ['murder'], ['violence', 'romantic'], ['atmospheric'], ['comedy', 'psychedelic', 'suspenseful'], ['romantic', 'depressing'], ['romantic'], ['sentimental'], ['violence', 'suspenseful'], ['romantic'], ['mystery', 'atmospheric', 'romantic'], ['atmospheric'], ['romantic', 'comedy'], ['suspenseful', 'humor'], ['violence'], ['romantic'], ['tragedy', 'romantic', 'violence'], ['humor', 'romantic', 'sentimental'], ['violence'], ['murder'], ['romantic'], ['tragedy', 'romantic'], ['violence', 'atmospheric'], ['action'], ['romantic', 'humor'], ['suspenseful', 'action', 'humor'], ['romantic'], ['romantic'], ['romantic'], ['suspenseful'], ['atmospheric', 'romantic'], ['humor', 'suspenseful'], ['fantasy', 'humor'], ['dramatic', 'violence', 'suspenseful'], ['action', 'romantic', 'tragedy'], ['horror', 'atmospheric', 'suspenseful'], ['comedy', 'dark', 'atmospheric', 'humor'], ['tragedy', 'humor'], ['comedy'], ['tragedy'], ['comedy'], ['depressing'], ['suspenseful'], ['violence'], ['violence', 'romantic'], ['suspenseful'], ['violence', 'action', 'suspenseful'], ['romantic'], ['violence', 'boring'], ['mystery', 'violence', 'atmospheric'], ['suspenseful', 'cult', 'romantic'], ['comedy'], ['dark', 'suspenseful', 'realism', 'violence', 'sadist'], ['mystery', 'comedy', 'suspenseful'], ['comedy', 'dark', 'cute', 'humor'], ['mystery', 'sadist'], ['violence', 'atmospheric', 'suspenseful'], ['comedy', 'atmospheric', 'inspiring'], ['suspenseful', 'violence', 'sadist'], ['mystery'], ['boring', 'fantasy', 'cute'], ['romantic', 'depressing'], ['mystery', 'cult', 'violence', 'suspenseful'], ['humor'], ['horror', 'suspenseful', 'sadist'], ['dark', 'suspenseful', 'mystery', 'bleak', 'violence', 'revenge'], ['bleak', 'atmospheric'], ['romantic'], ['boring', 'absurd'], ['mystery', 'revenge', 'suspenseful'], ['romantic'], ['bleak', 'atmospheric', 'violence'], ['suspenseful'], ['atmospheric', 'suspenseful'], ['romantic', 'cute', 'sentimental'], ['suspenseful', 'violence'], ['boring'], ['murder', 'violence'], ['violence'], ['comedy', 'violence'], ['violence', 'boring', 'romantic'], ['action'], ['dark', 'violence', 'atmospheric', 'romantic'], ['cult', 'claustrophobic'], ['suspenseful'], ['humor'], ['comedy', 'absurd', 'comic'], ['comedy', 'dark', 'depressing', 'mystery', 'bleak', 'violence', 'atmospheric', 'humor', 'suspenseful'], ['murder', 'violence'], ['comedy', 'suspenseful', 'revenge'], ['action'], ['comedy', 'violence', 'humor'], ['dark', 'comedy', 'cult', 'violence', 'tragedy'], ['violence', 'comedy'], ['boring', 'atmospheric'], ['comedy', 'atmospheric'], ['horror', 'suspenseful', 'violence'], ['tragedy', 'humor', 'atmospheric'], ['depressing', 'dramatic', 'violence', 'sadist', 'sentimental'], ['mystery', 'boring'], ['humor', 'boring'], ['inspiring', 'suspenseful', 'mystery', 'dramatic'], ['depressing', 'comic'], ['comedy', 'fantasy', 'suspenseful', 'dark', 'violence', 'horror', 'atmospheric', 'romantic', 'tragedy', 'sadist'], ['horror', 'violence'], ['suspenseful'], ['suspenseful', 'violence', 'horror'], ['mystery'], ['comedy', 'dramatic', 'atmospheric', 'humor'], ['violence'], ['comedy'], ['comedy', 'violence'], ['dark', 'boring', 'violence', 'atmospheric', 'romantic'], ['suspenseful'], ['mystery', 'dramatic', 'humor'], ['romantic'], ['action', 'boring'], ['boring'], ['suspenseful', 'comedy'], ['fantasy', 'violence', 'absurd', 'romantic'], ['violence'], ['comedy', 'suspenseful', 'horror', 'violence', 'action', 'entertaining', 'sadist'], ['tragedy', 'boring', 'atmospheric'], ['mystery'], ['comedy', 'violence'], ['depressing'], ['horror', 'violence',  ...

# %%
# df4.to_csv('all_data_mood.csv', sep=',', index=False)

# %%
df_mood.to_csv('all_data_mood3.csv', sep=',', index=False)

# %%
item_list_mood=[]
for i in range(len(item_list_ext_id)):
      item={'image_name': item_list_ext_id[i],
            'image_labels': item_list_ext_tag_list[i]}
      item_list_mood.append(item)
print(item_list_mood)
print(len(item_list_mood))
# Out:
# [{'image_name': 'tt0023427', 'image_labels': ['violence']}, {'image_name': 'tt0029583', 'image_labels': ['fantasy', 'cute', 'romantic']}, {'image_name': 'tt0031381', 'image_labels': ['romantic', 'boring']}, {'image_name': 'tt0032910', 'image_labels': ['cute', 'fantasy']}, {'image_name': 'tt0034492', 'image_labels': ['cute']}, {'image_name': 'tt0035896', 'image_labels': ['violence']}, {'image_name': 'tt0040746', 'image_labels': ['atmospheric', 'suspenseful']}, {'image_name': 'tt0041716', 'image_labels': ['romantic']}, {'image_name': 'tt0043274', 'image_labels': ['fantasy', 'cute']}, {'image_name': 'tt0043379', 'image_labels': ['violence', 'action']}, {'image_name': 'tt0044926', 'image_labels': ['romantic']}, {'image_name': 'tt0045125', 'image_labels': ['action']}, {'image_name': 'tt0045152', 'image_labels': ['comedy', 'boring', 'romantic']}, {'image_name': 'tt0045810', 'image_labels': ['romantic']}, {'image_name': 'tt0045963', 'image_labels': ['romantic']}, {'image_name': 'tt0046183', 'image_labels': ['fantasy', 'action']}, {'image_name': 'tt0046303', 'image_labels': ['violence']}, {'image_name': 'tt0046912', 'image_labels': ['suspenseful']}, {'image_name': 'tt0047396', 'image_labels': ['mystery', 'suspenseful', 'horror']}, {'image_name': 'tt0047472', 'image_labels': ['romantic']}, {'image_name': 'tt0047673', 'image_labels': ['romantic']}, {'image_name': 'tt0047834', 'image_labels': ['murder']}, {'image_name': 'tt0048545', 'image_labels': ['violence', 'romantic']}, {'image_name': 'tt0048728', 'image_labels': ['atmospheric']}, {'image_name': 'tt0049223', 'image_labels': ['comedy', 'psychedelic', 'suspenseful']}, {'image_name': 'tt0049261', 'image_labels': ['romantic', 'depressing']}, {'image_name': 'tt0049966', 'image_labels': ['romantic']}, {'image_name': 'tt0051459', 'image_labels': ['sentimental']}, {'image_name': 'tt0051554', 'image_labels': ['violence', 'suspenseful']}, {'image_name': 'tt0051658', 'image_labels': ['romantic']}, {'image_name': 'tt0052357', 'image_labels': ['mystery', 'atmospheric', 'romantic']}, {'image_name': 'tt0052905', 'image_labels': ['atmospheric']}, {'image_name': 'tt0053172', 'image_labels': ['romantic', 'comedy']}, {'image_name': 'tt0053221', 'image_labels': ['suspenseful', 'humor']}, {'image_name': 'tt0054047', 'image_labels': ['violence']}, {'image_name': 'tt0054195', 'image_labels': ['romantic']}, {'image_name': 'tt0054331', 'image_labels': ['tragedy', 'romantic', 'violence']}, {'image_name': 'tt0054698', 'image_labels': ['humor', 'romantic', 'sentimental']}, {'image_name': 'tt0054847', 'image_labels': ['violence']}, {'image_name': 'tt0055304', 'image_labels': ['murder']}, {'image_name': 'tt0055471', 'image_labels': ['romantic']}, {'image_name': 'tt0055614', 'image_labels': ['tragedy', 'romantic']}, {'image_name': 'tt0056172', 'image_labels': ['violence', 'atmospheric']}, {'image_name': 'tt0056264', 'image_labels': ['action']}, {'image_name': 'tt0056923', 'image_labels': ['romantic', 'humor']}, {'image_name': 'tt0058150', 'image_labels': ['suspenseful', 'action', 'humor']}, {'image_name': 'tt0058329', 'image_labels': ['romantic']}, {'image_name': 'tt0058385', 'image_labels': ['romantic']}, {'image_name': 'tt0058571', 'image_labels': ['romantic']}, {'image_name': 'tt0058672', 'image_labels': ['suspenseful']}, {'image_name': 'tt0059113', 'image_labels': ['atmospheric', 'romantic']}, {'image_name': 'tt0059800', 'image_labels': ['humor', 'suspenseful']}, {'image_name': 'tt0060345', 'image_labels': ['fantasy', 'humor']}, {'image_name': 'tt0063442', 'image_labels': ['dramatic', 'violence', 'suspenseful']}, {'image_name': 'tt0063518', 'image_labels': ['action', 'romantic', 'tragedy']}, {'image_name': 'tt0063522', 'image_labels': ['horror', 'atmospheric', 'suspenseful']}, {'image_name': 'tt0064276', 'image_labels': ['comedy', 'dark', 'atmospheric', 'humor']}, {'image_name': 'tt0064665', 'image_labels': ['tragedy', 'humor']}, {'image_name': 'tt0064782', 'image_labels': ['comedy']}, {'image_name': 'tt00650 ...
# 819

# %%
train_item=item_list_mood[:573]
val_item=item_list_mood[573:696]
test_item=item_list_mood[696:]


print(len(train_item))
print(len(val_item))
print(len(test_item))
# Out:
# 573
# 123
# 123

# %%
img_path=r'E:\NRF_2022\MDPI\Extracted_Data\new_stft_2024_mood_extracted2_split'

# %%
import json
with open(os.path.join(img_path, 'train', 'train_mood.json'), 'w') as fp:
    json.dump({'samples': train_item, 'labels': mood_tag_list}, fp, indent=3)

# %%
with open(os.path.join(img_path, 'val', 'val_mood.json'), 'w') as fp:
    json.dump({'samples': val_item, 'labels': mood_tag_list}, fp, indent=3)

# %%
with open(os.path.join(img_path, 'test', 'test_mood.json'), 'w') as fp:
    json.dump({'samples': test_item, 'labels': mood_tag_list}, fp, indent=3)
